# %%
import asyncio
from metagpt.roles import (
    Architect,
    Engineer,
    ProductManager,
    ProjectManager,
    QaEngineer
)
from metagpt.team import Team
async def startup(idea: str):
    company = Team()
    company.hire(
        [
            ProductManager(),
            Architect(),
            ProjectManager(),
            Engineer(),
            QaEngineer()
        ]
    )
    company.invest(investment=3.0)
    company.run_project(idea=idea)

    await company.run(n_round=5)
# Out:
# 2025-01-22 19:13:35.811 | INFO     | metagpt.const:get_metagpt_package_root:29 - Package root set to e:\wow-agent\notebook

# %%
await startup(idea="开发一个刷题程序，前端使用原生js和html，后端使用flask!")
# Out:
# 2025-01-22 19:13:41.265 | INFO     | metagpt.team:invest:90 - Investment: $3.0.
# 2025-01-22 19:13:41.268 | INFO     | metagpt.roles.role:_act:391 - Alice(Product Manager): to do PrepareDocuments(PrepareDocuments)
# 2025-01-22 19:13:41.726 | INFO     | metagpt.utils.file_repository:save:57 - save to: E:\wow-agent\notebook\workspace\20250122191341\docs\requirement.txt
# 2025-01-22 19:13:41.729 | INFO     | metagpt.roles.role:_act:391 - Alice(Product Manager): to do WritePRD(WritePRD)
# 2025-01-22 19:13:41.737 | INFO     | metagpt.actions.write_prd:run:86 - New requirement detected: 开发一个刷题程序，前端使用原生js和html，后端使用flask!
# [CONTENT]
# {
#     "Language": "zh_cn",
#     "Programming Language": "Python",
#     "Original Requirements": "开发一个刷题程序，前端使用原生js和html，后端使用flask!",
#     "Project Name": "practice_program",
#     "Product Goals": [
#         "提供一个高效的学习工具，帮助用户提高解题速度和准确性",
#         "确保程序的易用性和用户友好性，适合不同水平的学习者",
#         "提供实时反馈和统计功能，帮助用户跟踪学习进度"
#     ],
#     "User Stories": [
#         "作为一个学生，我希望可以自定义练习题目的难度和类型",
#         "作为一个学生，我希望可以查看我的答题正确率和平均用时",
#         "作为一个学生，我希望可以保存我的练习记录，以便日后复习",
#         "作为一个学生，我希望可以随时访问这个程序，无论是在电脑还是手机上",
#         "作为一个学生，我希望界面简洁明了，操作直观"
#     ],
#     "Competitive Analysis": [
#         "刷题网站A: 提供大量题目，但缺乏个性化设置",
#         "刷题网站B: 界面友好，但题目类型单一",
#         "刷题网站C: 题目难度可调，但反馈机制不完善",
#         "刷题网站D: 提供详细统计，但操作复杂",
#         "刷题网站E: 移动端适配良好，但题目数量有限"
#     ],
#     "Competitive Quadrant Chart": "quadrantChart\n    title \"刷题网站的覆盖范围和用户参与度\"\n    x-axis \"低覆盖范围\" --> \"高覆盖范围\"\n    y-axis \"低参与度\" --> \"高参与度\"\n    quadrant-1 \"我们应扩大\"\n    quadrant-2 \"需要推广\"\n    quadrant-3 \"重新评估\"\n    quadrant-4 \"可以改进\"\n    \"网站A\": [0.3, 0.6]\n    \"网站B\": [0.45, 0.23]\n    \"网站C\": [0.57, 0.69]\n    \"网站D\": [0.78, 0.34]\n    \"网站E\": [0.40, 0.34]\n    \"我们的目标产品\": [0.5, 0.6]",
#     "Requirement Analysis": "用户需要一个能够自定义练习题目的难度和类型的刷题程序，同时希望有实时反馈和统计功能来跟踪学习进度。程序需要在不同设备上都能良好运行。",
#     "Requirement Pool": [
#         [
#             "P0",
#             "实现前端界面，使用原生js和html"
#         ],
#         [
#             "P0",
#             "实现后端服务，使用flask框架"
#         ],
#         [
#             "P1",
#             "实现题目难度和类型的自定义功能"
#         ],
#         [
#             "P1",
#             "实现答题正确率和平均用时的统计功能"
#         ],
#         [
#             "P2",
#             "实现练习记录的保存功能"
#         ]
#     ],
#     "UI Design draft": "界面简洁明了，包含题目展示区、答题区、统计区和设置区。支持自定义设置和实时反馈。",
#     "Anything UNCLEAR": "需要进一步明确题目库的来源和更新机制。"
# }
# [/CONTENT]
# Warning: model not found. Using cl100k_base encoding.
# 2025-01-22 19:13:52.972 | WARNING  | metagpt.provider.openai_api:_calc_usage:244 - usage calculation failed: num_tokens_from_messages() is not implemented for model Qwen2.5-32B-Instruct-AWQ. See https://cookbook.openai.com/examples/how_to_count_tokens_with_tiktoken for information on how messages are converted to tokens.
# 2025-01-22 19:13:53.062 | WARNING  | metagpt.utils.git_repository:rename_root:214 - Move E:\wow-agent\notebook\workspace\20250122191341 to E:\wow-agent\notebook\workspace\practice_program error: [WinError 32] 另一个程序正在使用此文件，进程无法访问。: 'E:\\wow-agent\\notebook\\workspace\\20250122191341'
# 2025-01-22 19:13:53.064 | INFO     | metagpt.utils.git_repository:rename_root:219 - Rename directory E:\wow-agent\notebook\workspace\20250122191341 to E:\wow-agent\notebook\workspace\practice_program
# 2025-01-22 19:13:53.315 | INFO     | metagpt.utils.file_repository:save:57 - save to: E:\wow-agent\notebook\workspace\practice_program\docs\prd\20250122191353.json
# 2025-01-22 19:13:53.490 | WARNING  | metagpt.utils.mermaid:mermaid_to_file:35 - RUN `npm install -g @mermaid-js/mermaid-cli` to install mmdc,or consider changing engine to `playwright`, `pyppeteer`, or `ink`.
# 2025-01-22 19:13:53.493 | INFO     | metagpt.utils.file_repository:save:57 - save to: E:\wow-agent\notebook\workspace\practice_program\resources\prd\20250122191353.md
# 2025-01-22 19:13:53.496 | INFO     | metagpt.roles.role:_act:391 - Bob(Architect): to do WriteDesign(WriteDesign)
# [CONTENT]
# {
#     "Implementation approach": "我们将使用Flask框架来实现后端服务，利用原生JavaScript和HTML来构建前端界面。题目难度和类型的自定义功能将通过用户界面实现，统计功能将通过后端逻辑处理。我们将使用SQLite数据库来存储用户的练习记录。",
#     "File list": [
#         "app.py",
#         "models.py",
#         "routes.py",
#         "static/js/main.js",
#         "templates/index.html"
#     ],
#     "Data structures and interfaces": "\nclassDiagram\n    class App {\n        +run()\n    }\n    class User {\n        -id: int\n        -username: str\n        -practice_records: list\n        +add_record(record: dict)\n    }\n    class PracticeRecord {\n        -user_id: int\n        -question_id: int\n        -difficulty: str\n        -type: str\n        -correct: bool\n        -time_spent: float\n        +to_dict() dict\n    }\n    class Question {\n        -id: int\n        -difficulty: str\n        -type: str\n        -content: str\n        +to_dict() dict\n    }\n    class Database {\n        -conn: sqlite3.Connection\n        -cursor: sqlite3.Cursor\n        +init()\n        +add_user(user: User)\n        +add_record(record: PracticeRecord)\n        +get_user(id: int) User\n        +get_records(user_id: int) list\n    }\n    App --> User\n    User --> PracticeRecord\n    User --> Database\n    PracticeRecord --> Database\n    Question --> Database\n",
#     "Program call flow": "\nsequenceDiagram\n    participant User as 用户\n    participant App as 应用\n    participant Database as 数据库\n    participant Question as 题目\n    participant PracticeRecord as 练习记录\n    User->>App: 请求题目\n    App->>Database: 获取题目\n    Database-->>App: 返回题目\n    App-->>User: 展示题目\n    User->>App: 提交答案\n    App->>Question: 验证答案\n    Question-->>App: 返回正确性\n    App->>PracticeRecord: 创建记录\n    PracticeRecord-->>App: 返回记录\n    App->>Database: 保存记录\n    Database-->>App: 确认保存\n    App-->>User: 提供反馈\n",
#     "Anything UNCLEAR": "需要进一步明确题目库的来源和更新机制。
# 2025-01-22 19:14:02.739 | WARNING  | metagpt.provider.openai_api:_calc_usage:244 - usage calculation failed: num_tokens_from_messages() is not implemented for model Qwen2.5-32B-Instruct-AWQ. See https://cookbook.openai.com/examples/how_to_count_tokens_with_tiktoken for information on how messages are converted to tokens.
# 2025-01-22 19:14:02.744 | INFO     | metagpt.utils.file_repository:save:57 - save to: E:\wow-agent\notebook\workspace\practice_program\docs\system_design\20250122191353.json
# 2025-01-22 19:14:02.745 | INFO     | metagpt.utils.file_repository:save:62 - update dependency: E:\wow-agent\notebook\workspace\practice_program\docs\system_design\20250122191353.json:{'docs\\prd\\20250122191353.json'}
# 2025-01-22 19:14:02.899 | WARNING  | metagpt.utils.mermaid:mermaid_to_file:35 - RUN `npm install -g @mermaid-js/mermaid-cli` to install mmdc,or consider changing engine to `playwright`, `pyppeteer`, or `ink`.
# "
# }
# [/CONTENT]
# Warning: model not found. Using cl100k_base encoding.
# 2025-01-22 19:14:02.900 | INFO     | metagpt.actions.design_api:_save_data_api_design:107 - Save class view to E:\wow-agent\notebook\workspace\practice_program\resources\data_api_design\20250122191353
# 2025-01-22 19:14:03.055 | WARNING  | metagpt.utils.mermaid:mermaid_to_file:35 - RUN `npm install -g @mermaid-js/mermaid-cli` to install mmdc,or consider changing engine to `playwright`, `pyppeteer`, or `ink`.
# 2025-01-22 19:14:03.056 | INFO     | metagpt.actions.design_api:_save_seq_flow:116 - Saving sequence flow to E:\wow-agent\notebook\workspace\practice_program\resources\seq_flow\20250122191353
# 2025-01-22 19:14:03.058 | INFO     | metagpt.utils.file_repository:save:57 - save to: E:\wow-agent\notebook\workspace\practice_program\resources\system_design\20250122191353.md
# 2025-01-22 19:14:03.061 | INFO     | metagpt.roles.role:_act:391 - Eve(Project Manager): to do WriteTasks(WriteTasks)
# [CONTENT]
# {
#     "Required Python packages": [
#         "flask==1.1.2",
#         "sqlite3==3.3.0"
#     ],
#     "Required Other language third-party packages": [
#         "No third-party dependencies required"
#     ],
#     "Logic Analysis": [
#         [
#             "app.py",
#             "Contains App class and run method, initializes Flask app and routes"
#         ],
#         [
#             "models.py",
#             "Contains User, PracticeRecord, Question, and Database classes with their respective methods"
#         ],
#         [
#             "routes.py",
#             "Contains route functions for handling requests and responses, imports from models and app"
#         ],
#         [
#             "static/js/main.js",
#             "Contains JavaScript functions for handling user interactions and sending requests to the backend"
#         ],
#         [
#             "templates/index.html",
#             "HTML template for the frontend, includes JavaScript for dynamic content"
#         ]
#     ],
#     "Task list": [
#         "models.py",
#         "app.py",
#         "routes.py",
#         "static/js/main.js",
#         "templates/index.html"
#     ],
#     "Full API spec": "",
# 2025-01-22 19:14:08.315 | WARNING  | metagpt.provider.openai_api:_calc_usage:244 - usage calculation failed: num_tokens_from_messages() is not implemented for model Qwen2.5-32B-Instruct-AWQ. See https://cookbook.openai.com/examples/how_to_count_tokens_with_tiktoken for information on how messages are converted to tokens.
# 2025-01-22 19:14:08.321 | INFO     | metagpt.utils.file_repository:save:57 - save to: E:\wow-agent\notebook\workspace\practice_program\docs\task\20250122191353.json
# 2025-01-22 19:14:08.323 | INFO     | metagpt.utils.file_repository:save:62 - update dependency: E:\wow-agent\notebook\workspace\practice_program\docs\task\20250122191353.json:{'docs\\system_design\\20250122191353.json'}
# 2025-01-22 19:14:08.325 | INFO     | metagpt.utils.file_repository:save:57 - save to: E:\wow-agent\notebook\workspace\practice_program\requirements.txt
#  "Shared Knowledge": "数据库操作和用户交互逻辑需要在各个文件中保持一致。",
#     "Anything UNCLEAR": "需要进一步明确题目库的来源和更新机制。"
# }
# [/CONTENT]
# Warning: model not found. Using cl100k_base encoding.
# 2025-01-22 19:14:08.742 | INFO     | metagpt.actions.write_code:run:141 - Writing models.py..
# ## Code: models.py
# ```python
# ## models.py
# import sqlite3
# from typing import List, Dict
#
# class User:
#     def __init__(self, id: int, username: str):
#         self.id = id
#         self.username = username
#         self.practice_records: List[Dict] = []
#
#     def add_record(self, record: Dict):
#         self.practice_records.append(record)
#
# class PracticeRecord:
#     def __init__(self, user_id: int, question_id: int, difficulty: str, type: str, correct: bool, time_spent: float):
#         self.user_id = user_id
#         self.question_id = question_id
#         self.difficulty = difficulty
#         self.type = type
#         self.correct = correct
#         self.time_spent = time_spent
#
#     def to_dict(self) -> Dict:
#         return {
#             'user_id': self.user_id,
#             'question_id': self.question_id,
#             'difficulty': self.difficulty,
#             'type': self.type,
#             'correct': self.correct,
#             'time_spent': self.time_spent
#         }
#
# class Question:
#     def __init__(self, id: int, difficulty: str, type: str, content: str):
#         self.id = id
#         self.difficulty = difficulty
#         self.type = type
#         self.content = content
#
#     def to_dict(self) -> Dict:
#         return {
#             'id': self.id,
#             'difficulty': self.difficulty,
#             'type': self.type,
#             'content': self.content
#         }
#
# class Database:
#     def __init__(self, db_name: str = 'practice.db'):
#         self.conn = sqlite3.connect(db_name)
#         self.cursor = self.conn.cursor()
#         self.init()
#
#     def init(self):
#         self.cursor.execute('''
#             CREATE TABLE IF NOT EXISTS users (
#                 id INTEGER PRIMARY KEY,
#                 username TEXT NOT NULL
#             )
#         ''')
#         self.cursor.execute('''
#             CREATE TABLE IF NOT EXISTS practice_records (
#                 user_id INTEGER,
#                 question_id INTEGER,
#                 difficulty TEXT,
#                 type TEXT,
#                 correct BOOLEAN,
#                 time_spent REAL,
#                 FOREIGN KEY(user_id) REFERENCES users(id)
#             )
#         ''')
#         self.conn.commit()
#
#     def add_user(self, user: User):
#         self.cursor.execute('''
#             INSERT INTO users (id, username) VALUES (?, ?)
#         ''', (user.id, user.username))
#         self.conn.commit()
#
#     def add_record(self, record: PracticeRecord):
#         self.cursor.execute('''
#             INSERT INTO practice_records (user_id, question_id, difficulty, type, correct, time_spent) VALUES (?, ?, ?, ?, ?, ?)
#         ''', (record.user_id, record.question_id, record.difficulty, record.type, record.correct, record.time_spent))
#         self.conn.commit()
#
#     def get_user(self, id: int) -> User:
#         self.cursor.execute('SELECT * FROM users WHERE id = ?', (id,))
#         user_data = self.cursor.fetchone()
#         if user_data:
#             user = User(id=user_data[0], username=user_data[1])
#             user.practice_records = self.get_records(user.id)
#             return user
#         return None
#
#     def get_records(self, user_id: int) -> List[Dict]:
#         self.cursor.execute('SELECT * FROM practice_records WHERE user_id = ?', (user_id,))
#         records = self.cursor.fetchall()
#         return [PracticeRecord(*record).to_dict
# 2025-01-22 19:14:19.907 | WARNING  | metagpt.provider.openai_api:_calc_usage:244 - usage calculation failed: num_tokens_from_messages() is not implemented for model Qwen2.5-32B-Instruct-AWQ. See https://cookbook.openai.com/examples/how_to_count_tokens_with_tiktoken for information on how messages are converted to tokens.
# 2025-01-22 19:14:19.914 | INFO     | metagpt.utils.file_repository:save:57 - save to: E:\wow-agent\notebook\workspace\practice_program\practice_program\models.py
# 2025-01-22 19:14:19.915 | INFO     | metagpt.utils.file_repository:save:62 - update dependency: E:\wow-agent\notebook\workspace\practice_program\practice_program\models.py:['docs\\task\\20250122191353.json', 'docs\\system_design\\20250122191353.json']
# 2025-01-22 19:14:19.919 | INFO     | metagpt.actions.write_code:run:141 - Writing app.py..
# () for record in records]
# ```
# Warning: model not found. Using cl100k_base encoding.
# ## Code: app.py
# ```python
# ## app.py
# from flask import Flask, jsonify, request
# from models import User, PracticeRecord, Question, Database
#
# app = Flask(__name__)
# db = Database()
#
# @app.route('/question', methods=['GET'])
# def get_question():
#     difficulty = request.args.get('difficulty', 'easy')
#     question_type = request.args.get('type', 'math')
#     question = db.get_question(difficulty, question_type)
#     return jsonify(question.to_dict())
#
# @app.route('/submit', methods=['POST'])
# def submit_answer():
#     data = request.json
#     user_id = data['user_id']
#     question_id = data['question_id']
#     user_answer = data['answer']
#     correct = db.check_answer(question_id, user_answer)
#     record = PracticeRecord(user_id, question_id, correct)
#     db.add_record(record)
#     return jsonify({'correct': correct})
#
# @app.route('/user_records', methods=['GET'])
# def get_user_records():
#     user_id = request.args.get('user_id')
#     records = db.get_records(user_id)
#     return jsonify([record.to_dict() for record in records])
#
# def run():
#     app.run(debug=True)
#
# if __name__ == '__main
# 2025-01-22 19:14:24.553 | WARNING  | metagpt.provider.openai_api:_calc_usage:244 - usage calculation failed: num_tokens_from_messages() is not implemented for model Qwen2.5-32B-Instruct-AWQ. See https://cookbook.openai.com/examples/how_to_count_tokens_with_tiktoken for information on how messages are converted to tokens.
# 2025-01-22 19:14:24.559 | INFO     | metagpt.utils.file_repository:save:57 - save to: E:\wow-agent\notebook\workspace\practice_program\practice_program\app.py
# 2025-01-22 19:14:24.562 | INFO     | metagpt.utils.file_repository:save:62 - update dependency: E:\wow-agent\notebook\workspace\practice_program\practice_program\app.py:['docs\\task\\20250122191353.json', 'docs\\system_design\\20250122191353.json']
# 2025-01-22 19:14:24.564 | INFO     | metagpt.actions.write_code:run:141 - Writing routes.py..
# __':
#     run()
# ```
# Warning: model not found. Using cl100k_base encoding.
# ## Code: routes.py
# ```python
# ## routes.py
# from flask import Flask, request, jsonify, render_template
# from models import User, PracticeRecord, Question, Database
#
# app = Flask(__name__)
# db = Database()
#
# @app.route('/')
# def index():
#     return render_template('index.html')
#
# @app.route('/get_question', methods=['GET'])
# def get_question():
#     question = db.get_question()
#     return jsonify(question.to_dict())
#
# @app.route('/submit_answer', methods=['POST'])
# def submit_answer():
#     data = request.get_json()
#     user_id = data['user_id']
#     question_id = data['question_id']
#     answer = data['answer']
#     time_spent = data['time_spent']
#
#     question = db.get_question_by_id(question_id)
#     is_correct = question.content == answer
#
#     record = PracticeRecord(user_id, question_id, question.difficulty, question.type, is_correct, time_spent)
#     db.add_record(record)
#
#     return jsonify({'correct': is_correct})
#
# @app.route('/get_records', methods=['GET'])
# def get_records():
#     user_id = request.args.get('user_id')
#     records = db.get_records(user_id)
#     return jsonify([record.to_dict() for record in records])
#
# if __name__ == '__main__':
#     app.run(debug=True)
# ```
# This code snippet follows the design provided in the context, ensuring that the Flask routes interact correctly with the `models` defined in `models.py`. The `Database` class is used to handle interactions with the SQLite database, and the routes are designed to handle
# 2025-01-22 19:14:30.320 | WARNING  | metagpt.provider.openai_api:_calc_usage:244 - usage calculation failed: num_tokens_from_messages() is not implemented for model Qwen2.5-32B-Instruct-AWQ. See https://cookbook.openai.com/examples/how_to_count_tokens_with_tiktoken for information on how messages are converted to tokens.
#  requests for questions, submission of answers, and retrieval of practice records.
# Warning: model not found. Using cl100k_base encoding.
# 2025-01-22 19:14:30.326 | INFO     | metagpt.utils.file_repository:save:57 - save to: E:\wow-agent\notebook\workspace\practice_program\practice_program\routes.py
# 2025-01-22 19:14:30.328 | INFO     | metagpt.utils.file_repository:save:62 - update dependency: E:\wow-agent\notebook\workspace\practice_program\practice_program\routes.py:['docs\\task\\20250122191353.json', 'docs\\system_design\\20250122191353.json']
# 2025-01-22 19:14:30.330 | INFO     | metagpt.actions.write_code:run:141 - Writing static/js/main.js..
# ## Code: static/js/main.js
# ```javascript
# ## static/js/main.js
# document.addEventListener('DOMContentLoaded', function() {
#     const questionContainer = document.getElementById('question-container');
#     const answerForm = document.getElementById('answer-form');
#     const answerInput = document.getElementById('answer-input');
#     const feedbackContainer = document.getElementById('feedback-container');
#
#     // Function to fetch a question from the backend
#     function fetchQuestion() {
#         fetch('/api/question')
#             .then(response => response.json())
#             .then(data => {
#                 questionContainer.innerHTML = `
#                     <p>${data.content}</p>
#                     <input type="hidden" id="question-id" value="${data.id}">
#                     <input type="hidden" id="question-difficulty" value="${data.difficulty}">
#                     <input type="hidden" id="question-type" value="${data.type}">
#                 `;
#             })
#             .catch(error => console.error('Error fetching question:', error));
#     }
#
#     // Function to submit the user's answer
#     function submitAnswer(event) {
#         event.preventDefault();
#         const questionId = document.getElementById('question-id').value;
#         const answer = answerInput.value;
#         const difficulty = document.getElementById('question-difficulty').value;
#         const type = document.getElementById('question-type').value;
#
#         fetch('/api/submit-answer', {
#             method: 'POST',
#             headers: {
#                 'Content-Type': 'application/json',
#             },
#             body: JSON.stringify({
#                 question_id: questionId,
#                 answer: answer,
#                 difficulty: difficulty,
#                 type: type,
#             }),
#         })
#         .then(response => response.json())
#         .then(data => {
#             feedbackContainer.innerHTML = `<p>${data.feedback}</p>`;
#             answerForm.reset();
#             fetchQuestion();
#         })
#         .catch(error => console.error('Error submitting answer:', error));
#     }
#
#     // Attach event listeners
#     answerForm.addEventListener('submit', submitAnswer);
#
#     // Fetch the first question when the page loads
#     fetchQuestion();
# });
# ```
# This JavaScript file handles the interaction between the user and the backend for fetching questions and submitting answers. It ensures that the user interface is updated with the latest question and feedback after each submission.
# 2025-01-22 19:14:37.740 | WARNING  | metagpt.provider.openai_api:_calc_usage:244 - usage calculation failed: num_tokens_from_messages() is not implemented for model Qwen2.5-32B-Instruct-AWQ. See https://cookbook.openai.com/examples/how_to_count_tokens_with_tiktoken for information on how messages are converted to tokens.
# 2025-01-22 19:14:37.745 | INFO     | metagpt.utils.file_repository:save:57 - save to: E:\wow-agent\notebook\workspace\practice_program\practice_program\static\js\main.js
# 2025-01-22 19:14:37.749 | INFO     | metagpt.utils.file_repository:save:62 - update dependency: E:\wow-agent\notebook\workspace\practice_program\practice_program\static\js\main.js:['docs\\task\\20250122191353.json', 'docs\\system_design\\20250122191353.json']
# 2025-01-22 19:14:37.751 | INFO     | metagpt.actions.write_code:run:141 - Writing templates/index.html..
# Warning: model not found. Using cl100k_base encoding.
# ## Code: templates/index.html
# ```html
# ## templates/index.html
# <!DOCTYPE html>
# <html lang="zh">
# <head>
#     <meta charset="UTF-8">
#     <title>练习题目</title>
#     <script src="{{ url_for('static', filename='js/main.js') }}"></script>
# </head>
# <body>
#     <h1>练习题目</h1>
#     <div id="question-container">
#         <p id="question-content"></p>
#         <input type="text" id="answer-input" placeholder="请输入答案">
#         <button onclick="submitAnswer()">提交</button>
#     </div>
#     <div id="feedback-container">
#         <p id="feedback"></p>
#     </div>
# </body>
# </html>
# ```
# 此HTML模板用于构建前端界面，其中包含一个用于显示题目内容的段落，一个输入框供用户输入答案，一个提交按钮，以及一个用于显示反馈信息的段落。JavaScript文件`main.js`将处理用户交互和与后端的
# 2025-01-22 19:14:41.924 | WARNING  | metagpt.provider.openai_api:_calc_usage:244 - usage calculation failed: num_tokens_from_messages() is not implemented for model Qwen2.5-32B-Instruct-AWQ. See https://cookbook.openai.com/examples/how_to_count_tokens_with_tiktoken for information on how messages are converted to tokens.
# 2025-01-22 19:14:41.931 | INFO     | metagpt.utils.file_repository:save:57 - save to: E:\wow-agent\notebook\workspace\practice_program\practice_program\templates\index.html
# 2025-01-22 19:14:41.934 | INFO     | metagpt.utils.file_repository:save:62 - update dependency: E:\wow-agent\notebook\workspace\practice_program\practice_program\templates\index.html:['docs\\task\\20250122191353.json', 'docs\\system_design\\20250122191353.json']
# 通信。
# Warning: model not found. Using cl100k_base encoding.
# 2025-01-22 19:14:42.112 | INFO     | metagpt.utils.git_repository:archive:168 - Archive: ['.dependencies.json', 'docs/prd/20250122191353.json', 'docs/requirement.txt', 'docs/system_design/20250122191353.json', 'docs/task/20250122191353.json', 'practice_program/app.py', 'practice_program/models.py', 'practice_program/routes.py', 'practice_program/static/js/main.js', 'practice_program/templates/index.html', 'requirements.txt', 'resources/competitive_analysis/20250122191353.mmd', 'resources/data_api_design/20250122191353.mmd', 'resources/prd/20250122191353.md', 'resources/seq_flow/20250122191353.mmd', 'resources/system_design/20250122191353.md']
